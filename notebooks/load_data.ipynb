# %% [markdown]
# # Loading files

# %%
import pandas as pd
import json

# Load data from a CSV file
transactions = pd.read_csv("C:/Users/joshi/Desktop/DataScience/Working with Data/Assignment 2/Dataset/transactions_data.csv")
cards = pd.read_csv("C:/Users/joshi/Desktop/DataScience/Working with Data/Assignment 2/Dataset/cards_data.csv")
users = pd.read_csv("C:/Users/joshi/Desktop/DataScience/Working with Data/Assignment 2/Dataset/users_data.csv")
train_fraud = pd.read_csv("C:/Users/joshi/Desktop/DataScience/Working with Data/Assignment 2/Dataset/train_fraud_labels.csv")

transactions.head()
cards.head()
train_fraud.head()

# %%
# Loading JSON file to a dataframe using pandas

with open("C:/Users/joshi/Desktop/DataScience/Working with Data/Assignment 2/Dataset/mcc_codes.json", "r") as f:
    mcc_codes = json.load(f)

# Converting the dictionary into two columns: key + value to later convert it into a dataframe
mcc_df = pd.DataFrame(list(mcc_codes.items()), columns=["mcc_code", "description"])
mcc_df.head()
